# %% [markdown]
# # 🏆 TFT Leaderboard Crawler - VN2 Server

# %%
# ========================================
# CELL 1: CONFIG
# ========================================

import os
import requests
import time
import json
import pandas as pd
from datetime import datetime
from dotenv import load_dotenv

# load Riot API Key
load_dotenv()
RIOT_API_KEY = os.getenv("RIOT_API_KEY")

PLATFORM = "vn2"
REGION_ACCOUNT = "asia"
REGION_MATCH = "sea"

TOP_N = 70
MATCH_COUNT_PER_PLAYER = 200

print("✅ Config loaded!")
# Out:
# ✅ Config loaded!

# %%
# ========================================
# CELL 2: API FUNCTIONS
# ========================================

def make_api_request(url, params=None):
    headers = {"X-Riot-Token": RIOT_API_KEY}
    try:
        response = requests.get(url, headers=headers, params=params)
        if response.status_code == 200:
            return response.json()
        elif response.status_code == 429:
            retry_after = int(response.headers.get('Retry-After', 10))
            print(f"⏳ Rate limited. Waiting {retry_after}s...")
            time.sleep(retry_after)
            return make_api_request(url, params)
        return None
    except Exception as e:
        print(f"❌ Error: {e}")
        return None

def format_timestamp(timestamp_ms):
    return datetime.fromtimestamp(timestamp_ms / 1000).strftime('%Y-%m-%d %H:%M:%S')

def format_unit_info(unit):
    """Format thông tin chi tiết của một unit"""
    name = unit.get('character_id', 'Unknown')
    tier = unit.get('tier', 1)  # Star level (1-3)
    rarity = unit.get('rarity', 0)  # Cost (0=1cost, 1=2cost, etc)
    items = unit.get('itemNames', [])  # Item names
    
    # Rarity to cost mapping
    cost = rarity + 1
    
    # Format items
    items_str = '+'.join(items) if items else 'No items'
    
    return {
        'name': name,
        'tier': tier,
        'cost': cost,
        'items': items_str,
        'item_count': len(items)
    }

print("✅ Functions loaded!")
# Out:
# ✅ Functions loaded!

# %%
# ========================================
# CELL 3: FETCH LEADERBOARD
# ========================================

print("🏆 Fetching TFT Leaderboard...\n")

all_players = []

url = f"https://{PLATFORM}.api.riotgames.com/tft/league/v1/challenger"
data = make_api_request(url)
if data:
    entries = data.get('entries', [])
    for e in entries:
        e['tier'] = 'CHALLENGER'
        all_players.append(e)
    print(f"✅ Challenger: {len(entries)}")

if len(all_players) < TOP_N:
    url = f"https://{PLATFORM}.api.riotgames.com/tft/league/v1/grandmaster"
    data = make_api_request(url)
    if data:
        entries = data.get('entries', [])
        for e in entries:
            e['tier'] = 'GRANDMASTER'
            all_players.append(e)
        print(f"✅ Grandmaster: {len(entries)}")

all_players = sorted(all_players, key=lambda x: x.get('leaguePoints', 0), reverse=True)
top_players = all_players[:TOP_N]

print(f"\n🏆 Top {len(top_players)} selected!")
# Out:
# 🏆 Fetching TFT Leaderboard...
#
# ✅ Challenger: 450
#
# 🏆 Top 70 selected!

# %%
# ========================================
# CELL 4: GET RIOT IDs
# ========================================

print("📋 Fetching Riot IDs...\n")

top_players_detailed = []

for i, player in enumerate(top_players, 1):
    puuid = player.get('puuid')
    print(f"⏳ [{i}/{len(top_players)}] ", end="")
    
    if puuid:
        account_url = f"https://{REGION_ACCOUNT}.api.riotgames.com/riot/account/v1/accounts/by-puuid/{puuid}"
        account_data = make_api_request(account_url)
        
        if account_data:
            game_name = account_data.get('gameName', 'Unknown')
            tag_line = account_data.get('tagLine', 'VN2')
            riot_id = f"{game_name}#{tag_line}"
            
            info = {
                'rank': i,
                'riot_id': riot_id,
                'game_name': game_name,
                'tag_line': tag_line,
                'tier': player.get('tier'),
                'lp': player.get('leaguePoints', 0),
                'wins': player.get('wins', 0),
                'losses': player.get('losses', 0),
                'puuid': puuid
            }
            info['total_games'] = info['wins'] + info['losses']
            info['win_rate'] = round(info['wins'] / info['total_games'] * 100, 1) if info['total_games'] > 0 else 0
            
            top_players_detailed.append(info)
            print(f"✅ {riot_id} ({info['lp']} LP)")
        else:
            print(f"❌ Failed")
    else:
        print(f"❌ No PUUID")
    
    time.sleep(0.3)

print(f"\n✅ Got {len(top_players_detailed)} players!")
# Out:
# 📋 Fetching Riot IDs...
#
# ⏳ [1/70] ✅ Hoàng Đế Shurima#2911 (2103 LP)
# ⏳ [2/70] ✅ EA7 longbentre#0910 (1956 LP)
# ⏳ [3/70] ✅ k3tdc#1st (1898 LP)
# ⏳ [4/70] ✅ HnZ Luckyboiz#0912 (1859 LP)
# ⏳ [5/70] ✅ Chunj1#chun (1851 LP)
# ⏳ [6/70] ✅ TìmLạiChínhMình#0907 (1785 LP)
# ⏳ [7/70] ✅ YBY1#0615 (1747 LP)
# ⏳ [8/70] ✅ Kharik#1403 (1720 LP)
# ⏳ [9/70] ✅ Vô Ám Giả#1982 (1656 LP)
# ⏳ [10/70] ✅ VP Lê Chuyên#2311 (1650 LP)
# ⏳ [11/70] ✅ this game sucks#2501 (1647 LP)
# ⏳ [12/70] ✅ TrungNguyen#257 (1640 LP)
# ⏳ [13/70] ✅ BBQ FEEDLATAO#2508 (1640 LP)
# ⏳ [14/70] ✅ VP Maris#Maris (1636 LP)
# ⏳ [15/70] ✅ GD Royal#1704 (1595 LP)
# ⏳ [16/70] ✅ Mọc 6 Túi#n6m (1588 LP)
# ⏳ [17/70] ✅ VP Succulento#poggo (1561 LP)
# ⏳ [18/70] ✅ Quỷ Vương Đây#6262 (1549 LP)
# ⏳ [19/70] ✅ changes#DVu (1548 LP)
# ⏳ [20/70] ✅ Bánh Xíu Páo#2605 (1548 LP)
# ⏳ [21/70] ✅ HnZ  sơnsmaill#JAV (1548 LP)
# ⏳ [22/70] ✅ MeoM3o#3636 (1541 LP)
# ⏳ [23/70] ✅ SSC D2JP#1129 (1531 LP)
# ⏳ [24/70] ✅ Killua Zoldyc#1999 (1527 LP)
# ⏳ [25/70] ✅ MG Final#CKTG (1527 LP)
# ⏳ [26/70] ✅ Kashtira Fenrir#hanss (1524 LP)
# ⏳ [27/70] ✅ Dean#1711 (1523 LP)
# ⏳ [28/70] ✅ DR Chase#0612 (1517 LP)
# ⏳ [29/70] ✅ KNG Cchh#1005 (1516 LP)
# ⏳ [30/70] ✅ Stillness1#0910 (1511 LP)
    pd.set_option('display.max_rows', 50)
    display(leaderboard_df[['rank', 'riot_id', 'tier', 'lp', 'wins', 'losses', 'win_rate', 'total_games']])
# Out:
# 🏆 TFT LEADERBOARD - VN2 - TOP 70
#     rank                riot_id        tier    lp  wins  losses  win_rate  \
# 0      1  Hoàng Đế Shurima#2911  CHALLENGER  2103   249     100      71.3
# 1      2    EA7 longbentre#0910  CHALLENGER  1956   590     339      63.5
# 2      3              k3tdc#1st  CHALLENGER  1898   271     154      63.8
# 3      4     HnZ Luckyboiz#0912  CHALLENGER  1859   388     195      66.6
# 4      5            Chunj1#chun  CHALLENGER  1851   445     272      62.1
# ..   ...                    ...         ...   ...   ...     ...       ...
# 65    66    Em Chè đi CKTG#3007  CHALLENGER  1377   403     277      59.3
# 66    67             ynwxx#2105  CHALLENGER  1368   362     243      59.8
# 67    68        LifeSquare#2265  CHALLENGER  1363   493     429      53.5
# 68    69              Vic1#1309  CHALLENGER  1361   553     362      60.4
# 69    70      MF Mèo Hor1#colen  CHALLENGER  1359   468     387      54.7
#
#     total_games
# 0           349
# 1           929
# 2           425
# 3           583
# 4           717
# ..          ...
# 65          680
# 66          605
# 67          922
# 68          915
# 69          855
#
# [70 rows x 8 columns]

# %%
# ========================================
# CELL 6: FETCH MATCH HISTORY (với unit details)
# ========================================

if len(top_players_detailed) == 0:
    print("⚠️ No players to fetch.")
else:
    print(f"📊 Fetching match history ({MATCH_COUNT_PER_PLAYER} matches/player)...\n")
    
    all_player_stats = []  # Match stats
    all_unit_details = []  # Unit details per match
    
    for player in top_players_detailed:
        puuid = player['puuid']
        riot_id = player['riot_id']
        rank = player['rank']
        
        print(f"🎮 [{rank}] {riot_id} ", end="")
        
        match_url = f"https://{REGION_MATCH}.api.riotgames.com/tft/match/v1/matches/by-puuid/{puuid}/ids"
        match_ids = make_api_request(match_url, {"count": MATCH_COUNT_PER_PLAYER})
        
        if not match_ids:
            print("⚠️ No matches")
            continue
        
        matches_fetched = 0
        for match_id in match_ids:
            detail_url = f"https://{REGION_MATCH}.api.riotgames.com/tft/match/v1/matches/{match_id}"
            match_detail = make_api_request(detail_url)
            
            if match_detail:
                info = match_detail.get('info', {})
                for p in info.get('participants', []):
                    if p.get('puuid') == puuid:
                        # Traits
                        traits = [t['name'] for t in p.get('traits', []) if t.get('tier_current', 0) > 0]
                        
                        # Units với chi tiết
                        units = p.get('units', [])
                        unit_names = []
                        unit_details_str = []
                        
                        for unit in units:
                            unit_info = format_unit_info(unit)
                            unit_names.append(unit_info['name'])
                            
                            # Format: Name(tier★, cost$, items)
                            detail = f"{unit_info['name']}({unit_info['tier']}★{unit_info['cost']}$)"
                            if unit_info['item_count'] > 0:
                                detail += f"[{unit_info['items']}]"
                            unit_details_str.append(detail)
                            
                            # Lưu chi tiết riêng cho phân tích
                            all_unit_details.append({
                                'riot_id': riot_id,
                                'match_id': match_id,
                                'placement': p.get('placement'),
                                'unit_name': unit_info['name'],
                                'unit_tier': unit_info['tier'],
                                'unit_cost': unit_info['cost'],
                                'unit_items': unit_info['items'],
                                'item_count': unit_info['item_count']
                            })
                        
                        # Match stats
                        all_player_stats.append({
                            'riot_id': riot_id,
                            'leaderboard_rank': rank,
                            'match_id': match_id,
                            'datetime': format_timestamp(info.get('game_datetime', 0)),
                            'placement': p.get('placement'),
                            'level': p.get('level'),
                            'traits': ', '.join(traits[:5]),
                            'units': ', '.join(unit_names),
                            'units_detailed': ' | '.join(unit_details_str),
                            'num_units': len(units)
                        })
                        matches_fetched += 1
                        break
            time.sleep(0.25)
        
        print(f"✅ {matches_fetched} matches")
    
    print(f"\n✅ Total: {len(all_player_stats)} matches, {len(all_unit_details)} unit records")
# Out:
# 📊 Fetching match history (200 matches/player)...
#
# 🎮 [1] Hoàng Đế Shurima#2911 ✅ 200 matches
# 🎮 [2] EA7 longbentre#0910 ✅ 200 matches
# 🎮 [3] k3tdc#1st ⏳ Rate limited. Waiting 12s...
# ✅ 200 matches
# 🎮 [4] HnZ Luckyboiz#0912 ⏳ Rate limited. Waiting 69s...
# ⏳ Rate limited. Waiting 58s...
# ⏳ Rate limited. Waiting 55s...
# ⏳ Rate limited. Waiting 55s...
# ✅ 200 matches
# 🎮 [5] Chunj1#chun ⏳ Rate limited. Waiting 68s...
# ⏳ Rate limited. Waiting 66s...
# ⏳ Rate limited. Waiting 64s...
# ⏳ Rate limited. Waiting 54s...
# ⏳ Rate limited. Waiting 63s...
# ⏳ Rate limited. Waiting 67s...
# ✅ 200 matches
# 🎮 [6] TìmLạiChínhMình#0907 ⏳ Rate limited. Waiting 61s...
# ⏳ Rate limited. Waiting 69s...
# ⏳ Rate limited. Waiting 68s...
# ⏳ Rate limited. Waiting 65s...
# ⏳ Rate limited. Waiting 66s...
# ✅ 200 matches
# 🎮 [7] YBY1#0615 ⏳ Rate limited. Waiting 66s...
# ⏳ Rate limited. Waiting 61s...
# ⏳ Rate limited. Waiting 59s...
# ⏳ Rate limited. Waiting 61s...
# ⏳ Rate limited. Waiting 56s...
# ✅ 200 matches
# 🎮 [8] Kharik#1403 ⏳ Rate limited. Waiting 68s...
# ⏳ Rate limited. Waiting 65s...
# ⏳ Rate limited. Waiting 67s...
# ⏳ Rate limited. Waiting 63s...
# ⏳ Rate limited. Waiting 59s...
# ✅ 200 matches
# 🎮 [9] Vô Ám Giả#1982 ⏳ Rate limited. Waiting 52s...
# ⏳ Rate limited. Waiting 56s...
# ⏳ Rate limited. Waiting 59s...
# ⏳ Rate limited. Waiting 65s...
# ⏳ Rate limited. Waiting 69s...
# ✅ 200 matches
# 🎮 [10] VP Lê Chuyên#2311 ⏳ Rate limited. Waiting 59s...
# ⏳ Rate limited. Waiting 67s...
# ⏳ Rate limited. Waiting 67s...
# ⏳ Rate limited. Waiting 71s...
# ⏳ Rate limited. Waiting 71s...
# ✅ 200 matches
match_df = pd.DataFrame(all_player_stats) if 'all_player_stats' in dir() and all_player_stats else pd.DataFrame()
unit_df = pd.DataFrame(all_unit_details) if 'all_unit_details' in dir() and all_unit_details else pd.DataFrame()

print("💾 Saving...\n")

# Save leaderboard
if len(leaderboard_df) > 0:
    filename = f"tft_leaderboard_{PLATFORM}_top{TOP_N}.csv"
    leaderboard_df.to_csv(filename, index=False, encoding='utf-8-sig')
    print(f"✅ {filename}")

# Save match history
if len(match_df) > 0:
    filename = f"tft_matches_{PLATFORM}_top{TOP_N}.csv"
    match_df.to_csv(filename, index=False, encoding='utf-8-sig')
    print(f"✅ {filename}")

# Save unit details
if len(unit_df) > 0:
    filename = f"tft_units_{PLATFORM}_top{TOP_N}.csv"
    unit_df.to_csv(filename, index=False, encoding='utf-8-sig')
    print(f"✅ {filename}")

print("\n📊 Match History Preview:")
if len(match_df) > 0:
    display(match_df[['riot_id', 'placement', 'level', 'units_detailed']].head(10))

print("\n📊 Unit Details Preview:")
if len(unit_df) > 0:
    display(unit_df.head(20))

print("\n🎉 Done!")
# Out:
# 💾 Saving...
#
# ✅ tft_leaderboard_vn2_top40.csv
# ✅ tft_matches_vn2_top40.csv
# ✅ tft_units_vn2_top40.csv
#
# 📊 Match History Preview:
#                riot_id  placement  level  \
# 0  Ước gì bớt đẳng#010          3      8
# 1  Ước gì bớt đẳng#010          2     10
# 2  Ước gì bớt đẳng#010          2      8
# 3  Ước gì bớt đẳng#010          4      8
# 4  Ước gì bớt đẳng#010          7      8
# 5  Ước gì bớt đẳng#010          4      9
# 6  Ước gì bớt đẳng#010          1      9
# 7  Ước gì bớt đẳng#010          2      9
# 8  Ước gì bớt đẳng#010          5      9
# 9  Ước gì bớt đẳng#010          7      5
#
#                                       units_detailed
# 0  TFT16_Lulu(3★1$) | TFT16_Rumble(2★1$) | TFT16_...
# 1  TFT16_Nautilus(2★3$) | TFT16_MissFortune(2★5$)...
# 2  TFT16_JarvanIV(2★1$) | TFT16_Poppy(2★2$) | TFT...
# 3  TFT16_JarvanIV(3★1$)[TFT_Item_AdaptiveHelm] | ...
# 4  TFT16_Shen(2★1$)[TFT_Item_NegatronCloak] | TFT...
# 5  TFT16_Neeko(2★2$)[TFT_Item_NegatronCloak] | TF...
# 6  TFT16_Vi(2★2$) | TFT16_Orianna(2★2$) | TFT16_T...
# 7  TFT16_Sion(2★2$) | TFT16_Gangplank(1★3$) | TFT...
# 8  TFT16_Briar(1★1$) | TFT16_ChoGath(1★2$) | TFT1...
# 9  TFT16_JarvanIV(1★1$) | TFT16_Vi(1★2$) | TFT16_...
# 📊 Unit Details Preview:
#                 riot_id        match_id  placement           unit_name  \
# 0   Ước gì bớt đẳng#010  VN2_1239749291          3          TFT16_Lulu
# 1   Ước gì bớt đẳng#010  VN2_1239749291          3        TFT16_Rumble
# 2   Ước gì bớt đẳng#010  VN2_1239749291          3         TFT16_Teemo
# 3   Ước gì bớt đẳng#010  VN2_1239749291          3         TFT16_Poppy
# 4   Ước gì bớt đẳng#010  VN2_1239749291          3        TFT16_Kobuko
# 5   Ước gì bớt đẳng#010  VN2_1239749291          3        TFT16_Kennen
# 6   Ước gì bớt đẳng#010  VN2_1239749291          3        TFT16_Veigar
# 7   Ước gì bớt đẳng#010  VN2_1239749291          3          TFT16_Fizz
# 8   Ước gì bớt đẳng#010  VN2_1239700948          2      TFT16_Nautilus
# 9   Ước gì bớt đẳng#010  VN2_1239700948          2   TFT16_MissFortune
# 10  Ước gì bớt đẳng#010  VN2_1239700948          2         TFT16_Taric
# 11  Ước gì bớt đẳng#010  VN2_1239700948          2     TFT16_Seraphine
# 12  Ước gì bớt đẳng#010  VN2_1239700948          2       TFT16_Skarner
# 13  Ước gì bớt đẳng#010  VN2_1239700948          2         TFT16_Swain
# 14  Ước gì bớt đẳng#010  VN2_1239700948          2          TFT16_Azir
# 15  Ước gì bớt đẳng#010  VN2_1239700948          2  TFT16_Fiddlesticks
# 16  Ước gì bớt đẳng#010  VN2_1239700948          2        TFT16_Lucian
# 17  Ước gì bớt đẳng#010  VN2_1239700948          2       TFT16_Shyvana
# 18  Ước gì bớt đẳng#010  VN2_1239700948          2         TFT16_Brock
# 19  Ước gì bớt đẳng#010  VN2_1239700948          2         TFT16_Brock
#
#     unit_tier  unit_cost                                         unit_items  \
# 0           3          1                                           No items
# 1           2          1                                           No items
# 2           2          2                                           No items
# 3           2          2  TFT_Item_ThiefsGloves+TFT_Item_JeweledGauntlet...
# 4           3          3           TFT_Item_IonicSpark+TFT_Item_BrambleVest
# 5           3          3  TFT_Item_RedBuff+TFT_Item_Redemption+TFT_Item_...
# 6           3          5  TFT_Item_RabadonsDeathcap+TFT_Item_PowerGauntl...
# 7           3          5  TFT_Item_JeweledGauntlet+TFT_Item_UnstableConc...
# 8           2          3                                           No items
# 9           2          5  TFT_Item_PowerGauntlet+TFT_Item_GuinsoosRageblade
# 10          1          5                                           No items
# 11          1          5                                           No items
# 12          1          5                                           No items
# 13          2          5  TFT16_Item_ZaunEmblemItem+TFT16_Item_IxtalEmbl...
# 14          1          7  TFT_Item_ThiefsGloves+TFT_Item_EmptyBag+TFT_It...
# 15          1          7                        TFT_Item_UnstableConcoction
# 16          1          7       TFT_Item_Morellonomicon+TFT_Item_StatikkShiv
# 17          1          7      TFT_Item_ForceOfNature+TFT_Item_ForceOfNature
# 18          2          8  TFT_Item_ThiefsGloves+TFT_Item_EmptyBag+TFT_It...
# 19          2          8  TFT5_Item_AdaptiveHelmRadiant+TFT5_Item_Brambl...
#
#     item_count
# 0            0
# 1            0
# 2            0
# 3            3
# 4            2
# 5            3
# 6            3
# 7            3
# 8            0
# 9            2
# 10           0
# 11           0
# 12           0
# 13           3
# 14           3
# 15           1
# 16           2
# 17           2
# 18           3
# 19           3
# 🎉 Done!

# %%
# ========================================
# CELL 8: ANALYZE UNITS
# ========================================

if len(unit_df) > 0:
    print("📊 UNIT ANALYSIS\n")
    
    # Most used units
    print("🔥 Most Used Units:")
    unit_counts = unit_df['unit_name'].value_counts().head(15)
    for unit, count in unit_counts.items():
        print(f"   {unit}: {count}")
    
    # Most common 3-star units
    print("\n⭐ Most Common 3-Star Units:")
    three_star = unit_df[unit_df['unit_tier'] == 3]['unit_name'].value_counts().head(10)
    for unit, count in three_star.items():
        print(f"   {unit}: {count}")
    
    # Most common items
    print("\n🛡️ Most Common Items:")
    all_items = []
    for items_str in unit_df['unit_items'].dropna():
        if items_str and items_str != 'No items':
            items = items_str.split('+')
            all_items.extend(items)
    
    item_counts = pd.Series(all_items).value_counts().head(15)
    for item, count in item_counts.items():
        print(f"   {item}: {count}")
    
    # Units with most items
    print("\n🎯 Units with Most Items:")
    carry_units = unit_df[unit_df['item_count'] >= 3].groupby('unit_name').size().sort_values(ascending=False).head(10)
    for unit, count in carry_units.items():
        print(f"   {unit}: {count} times with 3+ items")
# Out:
# 📊 UNIT ANALYSIS
#
# 🔥 Most Used Units:
#    TFT16_Swain: 51
#    TFT16_Vi: 45
#    TFT16_Seraphine: 39
#    TFT16_Taric: 38
#    TFT16_Shyvana: 38
#    TFT16_Wukong: 26
#    TFT16_Azir: 25
#    TFT16_Lucian: 24
#    TFT16_Lissandra: 23
#    TFT16_Braum: 22
#    TFT16_Fiddlesticks: 21
#    TFT16_Loris: 20
#    TFT16_Neeko: 18
#    TFT16_Sejuani: 18
#    TFT16_Orianna: 17
#
# ⭐ Most Common 3-Star Units:
#    TFT16_Kennen: 3
#    TFT16_Neeko: 3
#    TFT16_Orianna: 3
#    TFT16_Lux: 2
#    TFT16_MissFortune: 2
#    TFT16_Qiyana: 2
#    TFT16_Milio: 2
#    TFT16_Bard: 2
#    TFT16_TwistedFate: 2
#    TFT16_Lulu: 1
#
# 🛡️ Most Common Items:
#    TFT_Item_JeweledGauntlet: 66
#    TFT_Item_SpearOfShojin: 48
#    TFT_Item_ThiefsGloves: 46
#    TFT_Item_GargoyleStoneplate: 42
#    TFT_Item_FrozenHeart: 42
#    TFT_Item_WarmogsArmor: 41
#    TFT_Item_Leviathan: 37
#    TFT_Item_Morellonomicon: 37
#    TFT_Item_Redemption: 36
#    TFT_Item_GuinsoosRageblade: 36
#    TFT_Item_DragonsClaw: 36
#    TFT_Item_InfinityEdge: 35
#    TFT_Item_AdaptiveHelm: 35
#    TFT_Item_SteraksGage: 34
#    TFT_Item_Bloodthirster: 33
#
# 🎯 Units with Most Items:
#    TFT16_Seraphine: 22 times with 3+ items
#    TFT16_Taric: 20 times with 3+ items
#    TFT16_Wukong: 20 times with 3+ items
#    TFT16_Lissandra: 15 times with 3+ items
#    TFT16_Shyvana: 15 times with 3+ items
#    TFT16_Braum: 14 times with 3+ items
#    TFT16_Swain: 14 times with 3+ items
#    TFT16_AurelionSol: 13 times with 3+ items
#    TFT16_Yunara: 13 times with 3+ items
#    TFT16_Warwick: 10 times with 3+ items
