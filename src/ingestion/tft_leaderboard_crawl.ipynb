# %% [markdown]
# # 🏆 TFT Leaderboard Crawler - VN2 Server

# %%
# !pip -q install requests pandas python-dotenv

# %%
pip install "numpy<2.0"
# Out:
# Collecting numpy<2.0
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 848.6 kB/s eta 0:00:00 0:00:01
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 5.9 MB/s eta 0:00:0000:0100:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.4.1
#     Uninstalling numpy-2.4.1:
#       Successfully uninstalled numpy-2.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# moshi-personaplex 0.1.0 requires huggingface-hub<0.25,>=0.24, but you have huggingface-hub 0.36.0 which is incompatible.
# moshi-personaplex 0.1.0 requires sphn<0.2,>=0.1.4, but you have sphn 0.2.1 which is incompatible.
# transformers 5.0.0 requires huggingface-hub<2.0,>=1.3.0, but you have huggingface-hub 0.36.0 which is incompatible.
# torchvision 0.21.0 requires torch==2.6.0, but you have torch 2.4.1 which is incompatible.
# numba 0.57.1 requires numpy<1.25,>=1.21, but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4
# Note: you may need to restart the kernel to use updated packages.

# %%
# ========================================
# CELL 1: CONFIG
# ========================================

import os
import requests
import time
import json
import pandas as pd
from datetime import datetime
from dotenv import load_dotenv

# load Riot API Key
load_dotenv()
RIOT_API_KEY = os.getenv("RIOT_API_KEY")

PLATFORM = "vn2"
REGION_ACCOUNT = "asia"
REGION_MATCH = "sea"

TOP_N = 150
MATCH_COUNT_PER_PLAYER = 200

print("✅ Config loaded!")
# Out:
# ✅ Config loaded!

# %%
# ========================================
# CELL 2: API FUNCTIONS
# ========================================

def make_api_request(url, params=None):
    headers = {"X-Riot-Token": RIOT_API_KEY}
    try:
        response = requests.get(url, headers=headers, params=params)
        if response.status_code == 200:
            return response.json()
        elif response.status_code == 429:
            retry_after = int(response.headers.get('Retry-After', 10))
            print(f"⏳ Rate limited. Waiting {retry_after}s...")
            time.sleep(retry_after)
            return make_api_request(url, params)
        return None
    except Exception as e:
        print(f"❌ Error: {e}")
        return None

def format_timestamp(timestamp_ms):
    return datetime.fromtimestamp(timestamp_ms / 1000).strftime('%Y-%m-%d %H:%M:%S')

def format_unit_info(unit):
    """Format thông tin chi tiết của một unit"""
    name = unit.get('character_id', 'Unknown')
    tier = unit.get('tier', 1)  # Star level (1-3)
    rarity = unit.get('rarity', 0)  # Cost (0=1cost, 1=2cost, etc)
    items = unit.get('itemNames', [])  # Item names
    
    # Rarity to cost mapping
    cost = rarity + 1
    
    # Format items
    items_str = '+'.join(items) if items else 'No items'
    
    return {
        'name': name,
        'tier': tier,
        'cost': cost,
        'items': items_str,
        'item_count': len(items)
    }

print("✅ Functions loaded!")
# Out:
# ✅ Functions loaded!

# %%
# ========================================
# CELL 3: FETCH LEADERBOARD
# ========================================

print("🏆 Fetching TFT Leaderboard...\n")

all_players = []

url = f"https://{PLATFORM}.api.riotgames.com/tft/league/v1/challenger"
data = make_api_request(url)
if data:
    entries = data.get('entries', [])
    for e in entries:
        e['tier'] = 'CHALLENGER'
        all_players.append(e)
    print(f"✅ Challenger: {len(entries)}")

if len(all_players) < TOP_N:
    url = f"https://{PLATFORM}.api.riotgames.com/tft/league/v1/grandmaster"
    data = make_api_request(url)
    if data:
        entries = data.get('entries', [])
        for e in entries:
            e['tier'] = 'GRANDMASTER'
            all_players.append(e)
        print(f"✅ Grandmaster: {len(entries)}")

all_players = sorted(all_players, key=lambda x: x.get('leaguePoints', 0), reverse=True)
top_players = all_players[:TOP_N]

print(f"\n🏆 Top {len(top_players)} selected!")
# Out:
# 🏆 Fetching TFT Leaderboard...
#
# ✅ Challenger: 450
#
# 🏆 Top 150 selected!

# %%
# ========================================
# CELL 4: GET RIOT IDs
# ========================================

print("📋 Fetching Riot IDs...\n")

top_players_detailed = []

for i, player in enumerate(top_players, 1):
    puuid = player.get('puuid')
    print(f"⏳ [{i}/{len(top_players)}] ", end="")
    
    if puuid:
        account_url = f"https://{REGION_ACCOUNT}.api.riotgames.com/riot/account/v1/accounts/by-puuid/{puuid}"
        account_data = make_api_request(account_url)
        
        if account_data:
            game_name = account_data.get('gameName', 'Unknown')
            tag_line = account_data.get('tagLine', 'VN2')
            riot_id = f"{game_name}#{tag_line}"
            
            info = {
                'rank': i,
                'riot_id': riot_id,
                'game_name': game_name,
                'tag_line': tag_line,
                'tier': player.get('tier'),
                'lp': player.get('leaguePoints', 0),
                'wins': player.get('wins', 0),
                'losses': player.get('losses', 0),
                'puuid': puuid
            }
            info['total_games'] = info['wins'] + info['losses']
            info['win_rate'] = round(info['wins'] / info['total_games'] * 100, 1) if info['total_games'] > 0 else 0
            
            top_players_detailed.append(info)
            print(f"✅ {riot_id} ({info['lp']} LP)")
        else:
            print(f"❌ Failed")
    else:
        print(f"❌ No PUUID")
    
    time.sleep(0.3)

print(f"\n✅ Got {len(top_players_detailed)} players!")
# Out:
# 📋 Fetching Riot IDs...
#
# ⏳ [1/150] ✅ Hoàng Đế Shurima#2911 (2103 LP)
# ⏳ [2/150] ✅ EA7 longbentre#0910 (1956 LP)
# ⏳ [3/150] ✅ k3tdc#1st (1898 LP)
# ⏳ [4/150] ✅ HnZ Luckyboiz#0912 (1859 LP)
# ⏳ [5/150] ✅ Chunj1#chun (1851 LP)
# ⏳ [6/150] ✅ TìmLạiChínhMình#0907 (1785 LP)
# ⏳ [7/150] ✅ YBY1#0615 (1747 LP)
# ⏳ [8/150] ✅ Kharik#1403 (1720 LP)
# ⏳ [9/150] ✅ Vô Ám Giả#1982 (1692 LP)
# ⏳ [10/150] ✅ BBQ FEEDLATAO#2508 (1672 LP)
# ⏳ [11/150] ✅ VP Lê Chuyên#2311 (1650 LP)
# ⏳ [12/150] ✅ this game sucks#2501 (1647 LP)
# ⏳ [13/150] ✅ TrungNguyen#257 (1640 LP)
# ⏳ [14/150] ✅ VP Maris#Maris (1636 LP)
# ⏳ [15/150] ✅ GD Royal#1704 (1595 LP)
# ⏳ [16/150] ✅ Mọc 6 Túi#n6m (1588 LP)
# ⏳ [17/150] ✅ VP Succulento#poggo (1561 LP)
# ⏳ [18/150] ✅ Quỷ Vương Đây#6262 (1549 LP)
# ⏳ [19/150] ✅ changes#DVu (1548 LP)
# ⏳ [20/150] ✅ Bánh Xíu Páo#2605 (1548 LP)
# ⏳ [21/150] ✅ HnZ  sơnsmaill#JAV (1548 LP)
# ⏳ [22/150] ✅ MeoM3o#3636 (1541 LP)
# ⏳ [23/150] ✅ SSC D2JP#1129 (1531 LP)
# ⏳ [24/150] ✅ Killua Zoldyc#1999 (1527 LP)
# ⏳ [25/150] ✅ MG Final#CKTG (1527 LP)
# ⏳ [26/150] ✅ Kashtira Fenrir#hanss (1524 LP)
# ⏳ [27/150] ✅ Dean#1711 (1523 LP)
# ⏳ [28/150] ✅ Stillness1#0910 (1521 LP)
# ⏳ [118/150] ✅ baby im back#Định (1250 LP)
# ⏳ [119/150] ✅ JP 4ttention#2000 (1250 LP)
# ⏳ [120/150] ✅ Hải An mất em#3009 (1250 LP)
# ⏳ [121/150] ✅ Hàn Lập#hzzzz (1245 LP)
# ⏳ [122/150] ✅ Tớ chọn cậu#1205 (1244 LP)
# ⏳ [123/150] ✅ hongduc1#2401 (1242 LP)
# ⏳ [124/150] ✅ MF Lemonss#0810 (1241 LP)
# ⏳ [125/150] ✅ EA7 Gnut#2004 (1239 LP)
# ⏳ [126/150] ✅ Chill chiu#chill (1237 LP)
# ⏳ [127/150] ✅ sự tĩnh lặng#1993 (1236 LP)
# ⏳ [128/150] ✅ 4Nine Fieren#Banh (1234 LP)
# ⏳ [129/150] ✅ từ con số 0#1407 (1234 LP)
# ⏳ [130/150] ✅ NNG Blade#148 (1234 LP)
# ⏳ [131/150] ✅ DamzVN#2969 (1234 LP)
# ⏳ [132/150] ✅ Emperor 大国王#1111 (1233 LP)
# ⏳ [133/150] ✅ tftiseasy#00000 (1232 LP)
# ⏳ [134/150] ✅ RNG Souma#189 (1230 LP)
# ⏳ [135/150] ✅ CP Romeo#Roeee (1226 LP)
# ⏳ [136/150] ✅ Dante#LTD (1225 LP)
# ⏳ [137/150] ✅ Hắc Vũ#19x (1224 LP)
# ⏳ [138/150] ✅ NguyenDuyHoanh#2001 (1220 LP)
# ⏳ [139/150] ✅ Tom Cat#meo (1217 LP)
# ⏳ [140/150] ✅ IronBug1#153 (1216 LP)
# ⏳ [141/150] ✅ VP Milo#EA7 (1213 LP)
# ⏳ [142/150] ✅ Alizabé Lan#2703 (1211 LP)
# ⏳ [143/150] ✅ MăngCụtTFT#Live (1209 LP)
# ⏳ [144/150] ✅ Hoang#0110 (1206 LP)
# ⏳ [145/150] ✅ NướcĐáiTinhKhiết#NDTK (1205 LP)
# ⏳ [146/150] ✅ vinsontheween#210 (1203 LP)
# ⏳ [147/150] ✅ MP thinhh1#1208 (1203 LP)
# ⏳ [148/150] ✅ Coriander#coang (1202 LP)
# ⏳ [149/150] ✅ sansaniuu#2301 (1201 LP)
# ⏳ [150/150] ✅ Capybara#4266 (1199 LP)
#
# ✅ Got 150 players!

# %%
# ========================================
# CELL 5: DISPLAY LEADERBOARD
# ========================================

leaderboard_df = pd.DataFrame(top_players_detailed)

if len(leaderboard_df) > 0:
    print(f"\n🏆 TFT LEADERBOARD - VN2 - TOP {len(leaderboard_df)}\n")
    pd.set_option('display.max_rows', 50)
    display(leaderboard_df[['rank', 'riot_id', 'tier', 'lp', 'wins', 'losses', 'win_rate', 'total_games']])
# Out:
# 🏆 TFT LEADERBOARD - VN2 - TOP 150
#      rank                riot_id        tier    lp  wins  losses  win_rate  \
# 0       1  Hoàng Đế Shurima#2911  CHALLENGER  2103   249     100      71.3
# 1       2    EA7 longbentre#0910  CHALLENGER  1956   590     339      63.5
# 2       3              k3tdc#1st  CHALLENGER  1898   271     154      63.8
# 3       4     HnZ Luckyboiz#0912  CHALLENGER  1859   388     195      66.6
# 4       5            Chunj1#chun  CHALLENGER  1851   445     272      62.1
# ..    ...                    ...         ...   ...   ...     ...       ...
# 145   146      vinsontheween#210  CHALLENGER  1203   278     212      56.7
# 146   147        MP thinhh1#1208  CHALLENGER  1203   239     203      54.1
# 147   148        Coriander#coang  CHALLENGER  1202   306     247      55.3
# 148   149         sansaniuu#2301  CHALLENGER  1201   296     226      56.7
# 149   150          Capybara#4266  CHALLENGER  1199   217     155      58.3
#
#      total_games
# 0            349
# 1            929
# 2            425
# 3            583
# 4            717
# ..           ...
# 145          490
# 146          442
# 147          553
# 148          522
# 149          372
#
# [150 rows x 8 columns]

# %%
# ========================================
# CELL 6: FETCH MATCH HISTORY (với unit details)
# ========================================

if len(top_players_detailed) == 0:
    print("⚠️ No players to fetch.")
else:
    print(f"📊 Fetching match history ({MATCH_COUNT_PER_PLAYER} matches/player)...\n")
    
    all_player_stats = []  # Match stats
    all_unit_details = []  # Unit details per match
    
    for player in top_players_detailed:
        puuid = player['puuid']
        riot_id = player['riot_id']
        rank = player['rank']
        
        print(f"🎮 [{rank}] {riot_id} ", end="")
        
        match_url = f"https://{REGION_MATCH}.api.riotgames.com/tft/match/v1/matches/by-puuid/{puuid}/ids"
        match_ids = make_api_request(match_url, {"count": MATCH_COUNT_PER_PLAYER})
        
        if not match_ids:
            print("⚠️ No matches")
            continue
        
        matches_fetched = 0
        for match_id in match_ids:
            detail_url = f"https://{REGION_MATCH}.api.riotgames.com/tft/match/v1/matches/{match_id}"
            match_detail = make_api_request(detail_url)
            
            if match_detail:
                info = match_detail.get('info', {})
                for p in info.get('participants', []):
                    if p.get('puuid') == puuid:
                        # Traits
                        traits = [t['name'] for t in p.get('traits', []) if t.get('tier_current', 0) > 0]
                        
                        # Units với chi tiết
                        units = p.get('units', [])
                        unit_names = []
                        unit_details_str = []
                        
                        for unit in units:
                            unit_info = format_unit_info(unit)
                            unit_names.append(unit_info['name'])
                            
                            # Format: Name(tier★, cost$, items)
                            detail = f"{unit_info['name']}({unit_info['tier']}★{unit_info['cost']}$)"
                            if unit_info['item_count'] > 0:
                                detail += f"[{unit_info['items']}]"
                            unit_details_str.append(detail)
                            
                            # Lưu chi tiết riêng cho phân tích
                            all_unit_details.append({
                                'riot_id': riot_id,
                                'match_id': match_id,
                                'placement': p.get('placement'),
                                'unit_name': unit_info['name'],
                                'unit_tier': unit_info['tier'],
                                'unit_cost': unit_info['cost'],
                                'unit_items': unit_info['items'],
                                'item_count': unit_info['item_count']
                            })
                        
                        # Match stats
                        all_player_stats.append({
                            'riot_id': riot_id,
                            'leaderboard_rank': rank,
                            'match_id': match_id,
                            'datetime': format_timestamp(info.get('game_datetime', 0)),
                            'placement': p.get('placement'),
                            'level': p.get('level'),
                            'traits': ', '.join(traits[:5]),
                            'units': ', '.join(unit_names),
                            'units_detailed': ' | '.join(unit_details_str),
                            'num_units': len(units)
                        })
                        matches_fetched += 1
                        break
            time.sleep(0.25)
        
        print(f"✅ {matches_fetched} matches")
    
    print(f"\n✅ Total: {len(all_player_stats)} matches, {len(all_unit_details)} unit records")
# Out:
# 📊 Fetching match history (200 matches/player)...
#
# 🎮 [1] Hoàng Đế Shurima#2911 ⏳ Rate limited. Waiting 12s...
# ⏳ Rate limited. Waiting 69s...
# ❌ Error: HTTPSConnectionPool(host='sea.api.riotgames.com', port=443): Max retries exceeded with url: /tft/match/v1/matches/VN2_
: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# ⏳ Rate limited. Waiting 68s...
# ✅ 199 matches
# 🎮 [13] TrungNguyen#257 ⏳ Rate limited. Waiting 69s...

# %%
# ========================================
# CELL 7: DISPLAY & SAVE DATA
# ========================================

match_df = pd.DataFrame(all_player_stats) if 'all_player_stats' in dir() and all_player_stats else pd.DataFrame()
unit_df = pd.DataFrame(all_unit_details) if 'all_unit_details' in dir() and all_unit_details else pd.DataFrame()

print("💾 Saving...\n")

# Save leaderboard
if len(leaderboard_df) > 0:
    filename = f"tft_leaderboard_{PLATFORM}_top{TOP_N}.csv"
    leaderboard_df.to_csv(filename, index=False, encoding='utf-8-sig')
    print(f"✅ {filename}")

# Save match history
if len(match_df) > 0:
    filename = f"tft_matches_{PLATFORM}_top{TOP_N}.csv"
    match_df.to_csv(filename, index=False, encoding='utf-8-sig')
    print(f"✅ {filename}")

# Save unit details
if len(unit_df) > 0:
    filename = f"tft_units_{PLATFORM}_top{TOP_N}.csv"
    unit_df.to_csv(filename, index=False, encoding='utf-8-sig')
    print(f"✅ {filename}")

print("\n📊 Match History Preview:")
if len(match_df) > 0:
    display(match_df[['riot_id', 'placement', 'level', 'units_detailed']].head(10))

print("\n📊 Unit Details Preview:")
if len(unit_df) > 0:
    display(unit_df.head(20))

print("\n🎉 Done!")
# Out:
# 💾 Saving...
#
# ✅ tft_leaderboard_vn2_top150.csv
# ✅ tft_matches_vn2_top150.csv
# ✅ tft_units_vn2_top150.csv
#
# 📊 Match History Preview:
#                  riot_id  placement  level  \
# 0  Hoàng Đế Shurima#2911          4      9
# 1  Hoàng Đế Shurima#2911          1      8
# 2  Hoàng Đế Shurima#2911          1     10
# 3  Hoàng Đế Shurima#2911          7      8
# 4  Hoàng Đế Shurima#2911          1     10
# 5  Hoàng Đế Shurima#2911          1      9
# 6  Hoàng Đế Shurima#2911          3      9
# 7  Hoàng Đế Shurima#2911          1      8
# 8  Hoàng Đế Shurima#2911          1     10
# 9  Hoàng Đế Shurima#2911          6      8
#
#                                       units_detailed
# 0  TFT16_KogMaw(2★1$) | TFT16_ChoGath(2★2$) | TFT...
# 1  TFT16_Vi(2★2$) | TFT16_Orianna(2★2$)[TFT_Item_...
# 2  TFT16_KogMaw(2★1$) | TFT16_Sion(2★2$) | TFT16_...
# 3  TFT16_Shen(2★1$) | TFT16_Ashe(1★2$) | TFT16_Ah...
# 4  TFT16_Vi(2★2$) | TFT16_Orianna(2★2$) | TFT16_S...
# 5  TFT16_Caitlyn(1★1$) | TFT16_Loris(1★3$) | TFT1...
# 6  TFT16_Neeko(2★2$) | TFT16_Vi(2★2$) | TFT16_Jin...
# 7  TFT16_Illaoi(2★1$) | TFT16_Sion(2★2$) | TFT16_...
# 8  TFT16_Illaoi(1★1$) | TFT16_TwistedFate(2★2$)[T...
# 9  TFT16_JarvanIV(2★1$) | TFT16_XinZhao(2★2$) | T...
# 📊 Unit Details Preview:
#                   riot_id        match_id  placement         unit_name  \
# 0   Hoàng Đế Shurima#2911  VN2_1240385846          4      TFT16_KogMaw
# 1   Hoàng Đế Shurima#2911  VN2_1240385846          4     TFT16_ChoGath
# 2   Hoàng Đế Shurima#2911  VN2_1240385846          4    TFT16_Malzahar
# 3   Hoàng Đế Shurima#2911  VN2_1240385846          4      TFT16_Kobuko
# 4   Hoàng Đế Shurima#2911  VN2_1240385846          4  TFT16_RiftHerald
# 5   Hoàng Đế Shurima#2911  VN2_1240385846          4       TFT16_Kaisa
# 6   Hoàng Đế Shurima#2911  VN2_1240385846          4    TFT16_Renekton
# 7   Hoàng Đế Shurima#2911  VN2_1240385846          4        TFT16_Azir
# 8   Hoàng Đế Shurima#2911  VN2_1240385846          4     TFT16_Shyvana
# 9   Hoàng Đế Shurima#2911  VN2_1240373128          1          TFT16_Vi
# 10  Hoàng Đế Shurima#2911  VN2_1240373128          1     TFT16_Orianna
# 11  Hoàng Đế Shurima#2911  VN2_1240373128          1     TFT16_Sejuani
# 12  Hoàng Đế Shurima#2911  VN2_1240373128          1       TFT16_Loris
# 13  Hoàng Đế Shurima#2911  VN2_1240373128          1   TFT16_Lissandra
# 14  Hoàng Đế Shurima#2911  VN2_1240373128          1   TFT16_Seraphine
# 15  Hoàng Đế Shurima#2911  VN2_1240373128          1       TFT16_Braum
# 16  Hoàng Đế Shurima#2911  VN2_1240373128          1        TFT16_Azir
# 17  Hoàng Đế Shurima#2911  VN2_1240360102          1      TFT16_KogMaw
# 18  Hoàng Đế Shurima#2911  VN2_1240360102          1        TFT16_Sion
# 19  Hoàng Đế Shurima#2911  VN2_1240360102          1     TFT16_Ambessa
#
#     unit_tier  unit_cost                                         unit_items  \
# 0           2          1                                           No items
# 1           2          2                                           No items
# 2           2          3  TFT16_Item_InvokerEmblemItem+TFT_Item_RapidFir...
# 3           2          3        TFT_Item_Redemption+TFT_Item_SparringGloves
# 4           2          5  TFT_Item_WarmogsArmor+TFT_Item_SpectralGauntle...
# 5           2          5  TFT_Item_SpearOfShojin+TFT_Item_PowerGauntlet+...
# 6           2          5  TFT16_Item_VoidEmblemItem+TFT16_Item_YordleEmb...
# 7           1          7                                           No items
# 8           2          7  TFT_Item_ThiefsGloves+TFT_Item_RedBuff+TFT_Ite...
# 9           2          2                                           No items
# 10          2          2                                TFT_Item_RecurveBow
# 11          2          3  TFT_Item_DragonsClaw+TFT_Item_FrozenHeart+TFT_...
# 12          2          3  TFT_Item_ThiefsGloves+TFT_Item_RunaansHurrican...
# 13          2          5  TFT_Item_UnstableConcoction+TFT_Item_StatikkSh...
# 14          3          5  TFT_Item_RabadonsDeathcap+TFT_Item_HextechGunb...
# 15          3          5  TFT_Item_FrozenHeart+TFT_Item_UnstableConcocti...
# 16          1          7                                           No items
# 17          2          1                                           No items
# 18          2          2                                           No items
# 19          2          5  TFT16_Item_VoidEmblemItem+TFT_Item_SparringGloves
#
#     item_count
# 0            0
# 1            0
# 2            3
# 3            2
# 4            3
# 5            3
# 6            3
# 7            0
# 8            3
# 9            0
# 10           1
# 11           3
# 12           3
# 13           3
# 14           3
# 15           3
# 16           0
# 17           0
# 18           0
# 19           2
# 🎉 Done!

# %%
# ========================================
# CELL 8: ANALYZE UNITS
# ========================================

if len(unit_df) > 0:
    print("📊 UNIT ANALYSIS\n")
    
    # Most used units
    print("🔥 Most Used Units:")
    unit_counts = unit_df['unit_name'].value_counts().head(15)
    for unit, count in unit_counts.items():
        print(f"   {unit}: {count}")
    
    # Most common 3-star units
    print("\n⭐ Most Common 3-Star Units:")
    three_star = unit_df[unit_df['unit_tier'] == 3]['unit_name'].value_counts().head(10)
    for unit, count in three_star.items():
        print(f"   {unit}: {count}")
    
    # Most common items
    print("\n🛡️ Most Common Items:")
    all_items = []
    for items_str in unit_df['unit_items'].dropna():
        if items_str and items_str != 'No items':
            items = items_str.split('+')
            all_items.extend(items)
    
    item_counts = pd.Series(all_items).value_counts().head(15)
    for item, count in item_counts.items():
        print(f"   {item}: {count}")
    
    # Units with most items
    print("\n🎯 Units with Most Items:")
    carry_units = unit_df[unit_df['item_count'] >= 3].groupby('unit_name').size().sort_values(ascending=False).head(10)
    for unit, count in carry_units.items():
        print(f"   {unit}: {count} times with 3+ items")
# Out:
# 📊 UNIT ANALYSIS
#
# 🔥 Most Used Units:
#    TFT16_Swain: 14782
#    TFT16_Taric: 11592
#    TFT16_Shyvana: 10080
#    TFT16_Vi: 8934
#    TFT16_Wukong: 8449
#    TFT16_Lucian: 8392
#    TFT16_Seraphine: 7657
#    TFT16_Fiddlesticks: 6154
#    TFT16_Neeko: 5877
#    TFT16_Kindred: 5641
#    TFT16_Azir: 5344
#    TFT16_Sett: 5149
#    TFT16_Braum: 4902
#    TFT16_Volibear: 4745
#    TFT16_Lissandra: 4292
#
# ⭐ Most Common 3-Star Units:
#    TFT16_Neeko: 1442
#    TFT16_Ekko: 989
#    TFT16_Vi: 885
#    TFT16_JarvanIV: 814
#    TFT16_TwistedFate: 778
#    TFT16_Caitlyn: 706
#    TFT16_Sona: 648
#    TFT16_Bard: 637
#    TFT16_Gangplank: 601
#    TFT16_Graves: 496
#
# 🛡️ Most Common Items:
#    TFT_Item_GuinsoosRageblade: 17040
#    TFT_Item_ThiefsGloves: 16568
#    TFT_Item_JeweledGauntlet: 15356
#    TFT_Item_Redemption: 13544
#    TFT_Item_InfinityEdge: 13036
#    TFT_Item_GargoyleStoneplate: 13017
#    TFT_Item_WarmogsArmor: 12801
#    TFT_Item_SpearOfShojin: 12559
#    TFT_Item_Bloodthirster: 12054
#    TFT_Item_RedBuff: 11823
#    TFT_Item_StatikkShiv: 10708
#    TFT_Item_FrozenHeart: 10453
#    TFT_Item_Morellonomicon: 10186
#    TFT_Item_AdaptiveHelm: 9593
#    TFT_Item_MadredsBloodrazor: 8989
#
# 🎯 Units with Most Items:
#    TFT16_Wukong: 4648 times with 3+ items
#    TFT16_Swain: 4053 times with 3+ items
#    TFT16_Taric: 3877 times with 3+ items
#    TFT16_Shyvana: 3586 times with 3+ items
#    TFT16_Seraphine: 3500 times with 3+ items
#    TFT16_Sett: 3481 times with 3+ items
#    TFT16_Lucian: 3326 times with 3+ items
#    TFT16_Ziggs: 3110 times with 3+ items
#    TFT16_Yunara: 2945 times with 3+ items
#    TFT16_Volibear: 2941 times with 3+ items
