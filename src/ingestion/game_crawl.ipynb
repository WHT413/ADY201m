# %% [markdown]
# # TFT Match History Crawler
# Lấy lịch sử đấu Teamfight Tactics từ tên người chơi sử dụng Riot API

# %%
# ========================================
# CELL 1: CONFIG
# ========================================

# Riot API Key - Lấy từ https://developer.riotgames.com/
RIOT_API_KEY = "YOUR_RIOT_API_KEY_HERE"

# Thông tin người chơi
GAME_NAME = "Hoàng Đế Shurima"  # Tên game (phần trước #)
TAG_LINE = "2911"            # Tag (phần sau #, ví dụ: VN2, EUW, NA1)

# Region settings
# Platform routing: vn2, euw1, na1, kr, jp1, etc.
PLATFORM = "vn2"

# Regional routing: americas, asia, europe, sea
REGION = "asia"

# Số lượng trận đấu muốn lấy (tối đa 200)
MATCH_COUNT = 20

# API URLs
ACCOUNT_API_URL = f"https://{REGION}.api.riotgames.com/riot/account/v1/accounts/by-riot-id/{GAME_NAME}/{TAG_LINE}"
MATCH_LIST_BASE_URL = f"https://sea.api.riotgames.com/tft/match/v1/matches/by-puuid"
MATCH_DETAIL_BASE_URL = f"https://sea.api.riotgames.com/tft/match/v1/matches"

print("✅ Config loaded successfully!")
print(f"📍 Player: {GAME_NAME}#{TAG_LINE}")
print(f"🌍 Region: {REGION} | Platform: {PLATFORM}")
print(f"📊 Will fetch {MATCH_COUNT} matches")
# Out:
# ✅ Config loaded successfully!
# 📍 Player: Hoàng Đế Shurima#2911
# 🌍 Region: asia | Platform: vn2
# 📊 Will fetch 20 matches

# %%
# ========================================
# CELL 2: IMPORTS & HELPER FUNCTIONS
# ========================================

import requests
import time
import json
from datetime import datetime
import pandas as pd

def make_api_request(url, params=None):
    """Gửi request đến Riot API với xử lý rate limit"""
    headers = {
        "X-Riot-Token": RIOT_API_KEY
    }
    
    try:
        response = requests.get(url, headers=headers, params=params)
        
        if response.status_code == 200:
            return response.json()
        elif response.status_code == 429:
            # Rate limited - wait and retry
            retry_after = int(response.headers.get('Retry-After', 10))
            print(f"⏳ Rate limited. Waiting {retry_after} seconds...")
            time.sleep(retry_after)
            return make_api_request(url, params)
        elif response.status_code == 404:
            print(f"❌ Not found: {url}")
            return None
        elif response.status_code == 403:
            print("❌ API Key invalid or expired. Please check your API_KEY.")
            return None
        else:
            print(f"❌ Error {response.status_code}: {response.text}")
            return None
    except Exception as e:
        print(f"❌ Request failed: {e}")
        return None

def format_timestamp(timestamp_ms):
    """Chuyển đổi timestamp (ms) sang datetime readable"""
    return datetime.fromtimestamp(timestamp_ms / 1000).strftime('%Y-%m-%d %H:%M:%S')

print("✅ Helper functions loaded!")
# Out:
# ✅ Helper functions loaded!

# %%
# ========================================
# CELL 3: GET PLAYER PUUID
# ========================================

print(f"🔍 Fetching PUUID for {GAME_NAME}#{TAG_LINE}...")

account_data = make_api_request(ACCOUNT_API_URL)

if account_data:
    puuid = account_data['puuid']
    print(f"✅ Found player!")
    print(f"   Game Name: {account_data.get('gameName', 'N/A')}")
    print(f"   Tag Line: {account_data.get('tagLine', 'N/A')}")
    print(f"   PUUID: {puuid[:20]}...")
else:
    puuid = None
    print("❌ Failed to get player PUUID. Check player name and tag.")
# Out:
# 🔍 Fetching PUUID for Hoàng Đế Shurima#2911...
# ✅ Found player!
#    Game Name: Hoàng Đế Shurima
#    Tag Line: 2911
#    PUUID: 2Ou-PECRAzzALWJKtg5v...

# %%
# ========================================
# CELL 4: GET MATCH HISTORY
# ========================================

if puuid:
    print(f"📋 Fetching {MATCH_COUNT} recent matches...")
    
    match_list_url = f"{MATCH_LIST_BASE_URL}/{puuid}/ids"
    params = {
        "count": MATCH_COUNT
    }
    
    match_ids = make_api_request(match_list_url, params)
    
    if match_ids:
        print(f"✅ Found {len(match_ids)} matches!")
        print("\n📝 Match IDs:")
        for i, match_id in enumerate(match_ids[:5], 1):
            print(f"   {i}. {match_id}")
        if len(match_ids) > 5:
            print(f"   ... and {len(match_ids) - 5} more")
    else:
        match_ids = []
        print("❌ Failed to get match history.")
else:
    match_ids = []
    print("⚠️ Skipping - PUUID not available.")
# Out:
# 📋 Fetching 20 recent matches...
# ✅ Found 20 matches!
#
# 📝 Match IDs:
#    1. VN2_1226241991
#    2. VN2_1226080788
#    3. VN2_1224936601
#    4. VN2_1224815517
#    5. VN2_1224364107
#    ... and 15 more

# %%
# ========================================
# CELL 5: GET MATCH DETAILS
# ========================================

matches_data = []

if match_ids:
    print(f"📊 Fetching details for {len(match_ids)} matches...")
    print("(This may take a while due to API rate limits)\n")
    
    for i, match_id in enumerate(match_ids, 1):
        print(f"⏳ [{i}/{len(match_ids)}] Fetching {match_id}...", end=" ")
        
        match_url = f"{MATCH_DETAIL_BASE_URL}/{match_id}"
        match_detail = make_api_request(match_url)
        
        if match_detail:
            matches_data.append(match_detail)
            print("✅")
        else:
            print("❌")
        
        # Small delay to avoid rate limiting
        time.sleep(0.5)
    
    print(f"\n✅ Successfully fetched {len(matches_data)} match details!")
else:
    print("⚠️ No matches to fetch.")
# Out:
# 📊 Fetching details for 20 matches...
# (This may take a while due to API rate limits)
#
# ⏳ [1/20] Fetching VN2_1226241991... ✅
# ⏳ [2/20] Fetching VN2_1226080788... ✅
# ⏳ [3/20] Fetching VN2_1224936601... ✅
# ⏳ [4/20] Fetching VN2_1224815517... ✅
# ⏳ [5/20] Fetching VN2_1224364107... ✅
# ⏳ [6/20] Fetching VN2_1224336208... ✅
# ⏳ [7/20] Fetching VN2_1224317477... ✅
# ⏳ [8/20] Fetching VN2_1224297973... ✅
# ⏳ [9/20] Fetching VN2_1219398294... ✅
# ⏳ [10/20] Fetching VN2_1219321060... ✅
# ⏳ [11/20] Fetching VN2_1217943125... ✅
# ⏳ [12/20] Fetching VN2_1217906219... ✅
# ⏳ [13/20] Fetching VN2_1217883002... ✅
# ⏳ [14/20] Fetching VN2_1216601396... ✅
# ⏳ [15/20] Fetching VN2_1215658429... ✅
# ⏳ [16/20] Fetching VN2_1212749007... ✅
# ⏳ [17/20] Fetching VN2_1212668560... ✅
# ⏳ [18/20] Fetching VN2_1212652117... ✅
# ⏳ [19/20] Fetching VN2_1212505615... ✅
# ⏳ [20/20] Fetching VN2_1212454459... ✅
#
# ✅ Successfully fetched 20 match details!

# %%
# ========================================
# CELL 6: PROCESS & DISPLAY RESULTS
# ========================================

def extract_player_stats(match_data, target_puuid):
    """Trích xuất thông tin của người chơi từ match data"""
    info = match_data.get('info', {})
    metadata = match_data.get('metadata', {})
    
    # Tìm participant của người chơi
    participants = info.get('participants', [])
    player_data = None
    
    for participant in participants:
        if participant.get('puuid') == target_puuid:
            player_data = participant
            break
    
    if not player_data:
        return None
    
    # Lấy traits (synergies)
    traits = player_data.get('traits', [])
    active_traits = [t['name'] for t in traits if t.get('tier_current', 0) > 0]
    
    # Lấy units (champions)
    units = player_data.get('units', [])
    unit_names = [u.get('character_id', 'Unknown') for u in units]
    
    return {
        'match_id': metadata.get('match_id', 'N/A'),
        'game_datetime': format_timestamp(info.get('game_datetime', 0)),
        'game_length': round(info.get('game_length', 0) / 60, 1),  # Convert to minutes
        'game_version': info.get('game_version', 'N/A'),
        'tft_set_number': info.get('tft_set_number', 'N/A'),
        'placement': player_data.get('placement', 'N/A'),
        'level': player_data.get('level', 'N/A'),
        'gold_left': player_data.get('gold_left', 0),
        'players_eliminated': player_data.get('players_eliminated', 0),
        'total_damage_to_players': player_data.get('total_damage_to_players', 0),
        'active_traits': ', '.join(active_traits[:5]),  # Top 5 traits
        'units': ', '.join(unit_names),
        'num_units': len(units)
    }

# Process all matches
if matches_data and puuid:
    results = []
    for match in matches_data:
        stats = extract_player_stats(match, puuid)
        if stats:
            results.append(stats)
    
    # Create DataFrame
    df = pd.DataFrame(results)
    
    print(f"\n📊 Match History for {GAME_NAME}#{TAG_LINE}")
    print("=" * 60)
    
    # Display summary
    if len(df) > 0:
        avg_placement = df['placement'].mean()
        top4_rate = (df['placement'] <= 4).sum() / len(df) * 100
        win_rate = (df['placement'] == 1).sum() / len(df) * 100
        
        print(f"\n📈 Summary Statistics:")
        print(f"   Total Matches: {len(df)}")
        print(f"   Avg Placement: {avg_placement:.2f}")
        print(f"   Top 4 Rate: {top4_rate:.1f}%")
        print(f"   Win Rate: {win_rate:.1f}%")
    
    # Display DataFrame
    display_cols = ['game_datetime', 'placement', 'level', 'game_length', 'active_traits']
    print("\n📋 Recent Matches:")
    display(df[display_cols].head(10))
else:
    print("⚠️ No match data to process.")
    df = pd.DataFrame()
# Out:
# 📊 Match History for Hoàng Đế Shurima#2911
# ============================================================
#
# 📈 Summary Statistics:
#    Total Matches: 20
#    Avg Placement: 3.40
#    Top 4 Rate: 65.0%
#    Win Rate: 25.0%
#
# 📋 Recent Matches:
#          game_datetime  placement  level  game_length  \
# 0  2026-01-20 13:48:42          1      8         36.6
# 1  2026-01-20 11:33:38          3      9         35.4
# 2  2026-01-19 16:43:27          3      9         32.4
# 3  2026-01-19 15:15:16          4      9         36.7
# 4  2026-01-19 08:04:15          1      8         32.2
# 5  2026-01-19 06:56:52          6      8         34.8
# 6  2026-01-19 05:59:48          3      9         35.4
# 7  2026-01-19 05:09:21          3     10         37.5
# 8  2026-01-16 01:57:52          2     10         34.9
# 9  2026-01-16 00:38:48          1      9         34.2
#
#                                        active_traits
# 0  TFT16_Defender, TFT16_Juggernaut, TFT16_Kindre...
# 1  TFT16_Bilgewater, TFT16_Brawler, TFT16_Glutton...
# 2  TFT16_Bilgewater, TFT16_Brawler, TFT16_Harvest...
# 3  TFT16_Brawler, TFT16_Defender, TFT16_Ionia, TF...
# 4  TFT16_Defender, TFT16_Emperor, TFT16_Magus, TF...
# 5  TFT16_Defender, TFT16_Demacia, TFT16_Ionia, TF...
# 6  TFT16_Defender, TFT16_Demacia, TFT16_Heroic, T...
# 7  TFT16_Chronokeeper, TFT16_Defender, TFT16_Dema...
# 8  TFT16_Bilgewater, TFT16_Brawler, TFT16_Glutton...
# 9  TFT16_Defender, TFT16_Demacia, TFT16_Heroic, T...

# %%
# ========================================
# CELL 7: SAVE DATA
# ========================================

if len(df) > 0:
    # Save to CSV
    filename = f"tft_history_{GAME_NAME}_{TAG_LINE}.csv"
    df.to_csv(filename, index=False, encoding='utf-8-sig')
    print(f"✅ Data saved to {filename}")
    
    # Save raw JSON for detailed analysis
    json_filename = f"tft_history_{GAME_NAME}_{TAG_LINE}_raw.json"
    with open(json_filename, 'w', encoding='utf-8') as f:
        json.dump(matches_data, f, ensure_ascii=False, indent=2)
    print(f"✅ Raw data saved to {json_filename}")
else:
    print("⚠️ No data to save.")
# Out:
# ✅ Data saved to tft_history_Hoàng Đế Shurima_2911.csv
# ✅ Raw data saved to tft_history_Hoàng Đế Shurima_2911_raw.json

# %%
# ========================================
# CELL 8: EXPORT FULL DATA
# ========================================

# Display full DataFrame with all columns
if len(df) > 0:
    print("📋 Full Match Data:\n")
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', None)
    display(df)
else:
    print("⚠️ No data available.")
# Out:
# 📋 Full Match Data:
#           match_id        game_datetime  game_length  \
# 0   VN2_1226241991  2026-01-20 13:48:42         36.6
# 1   VN2_1226080788  2026-01-20 11:33:38         35.4
# 2   VN2_1224936601  2026-01-19 16:43:27         32.4
# 3   VN2_1224815517  2026-01-19 15:15:16         36.7
# 4   VN2_1224364107  2026-01-19 08:04:15         32.2
# 5   VN2_1224336208  2026-01-19 06:56:52         34.8
# 6   VN2_1224317477  2026-01-19 05:59:48         35.4
# 7   VN2_1224297973  2026-01-19 05:09:21         37.5
# 8   VN2_1219398294  2026-01-16 01:57:52         34.9
# 9   VN2_1219321060  2026-01-16 00:38:48         34.2
# 10  VN2_1217943125  2026-01-15 04:51:29         36.3
# 11  VN2_1217906219  2026-01-15 03:20:17         32.2
# 12  VN2_1217883002  2026-01-15 02:35:34         35.8
# 13  VN2_1216601396  2026-01-14 10:59:30         35.6
# 14  VN2_1215658429  2026-01-13 19:33:14         33.8
# 15  VN2_1212749007  2026-01-11 21:58:05         36.8
# 16  VN2_1212668560  2026-01-11 21:15:55         33.1
# 17  VN2_1212652117  2026-01-11 20:34:31          1.7
# 18  VN2_1212505615  2026-01-11 19:42:02         34.1
# 19  VN2_1212454459  2026-01-11 19:01:33         33.7
#
#                                          game_version  tft_set_number  \
# 0   Linux Version 16.1.737.4870 (Jan 09 2026/19:00...              16
# 1   Linux Version 16.1.737.4870 (Jan 09 2026/19:00...              16
# 2   Linux Version 16.1.737.4870 (Jan 09 2026/19:00...              16
# 3   Linux Version 16.1.737.4870 (Jan 09 2026/19:00...              16
# 4   Linux Version 16.1.737.4870 (Jan 09 2026/19:00...              16
# 5   Linux Version 16.1.737.4870 (Jan 09 2026/19:00...              16
# 6   Linux Version 16.1.737.4870 (Jan 09 2026/19:00...              16
# 7   Linux Version 16.1.737.4870 (Jan 09 2026/19:00...              16
# 8   Linux Version 16.1.737.4870 (Jan 09 2026/19:00...              16
# 9   Linux Version 16.1.737.4870 (Jan 09 2026/19:00...              16
# 10  Linux Version 16.1.737.4870 (Jan 09 2026/19:00...              16
# 11  Linux Version 16.1.737.4870 (Jan 09 2026/19:00...              16
# 12  Linux Version 16.1.737.4870 (Jan 09 2026/19:00...              16
# 13  Linux Version 16.1.737.4870 (Jan 09 2026/19:00...              16
# 14  Linux Version 16.1.737.4870 (Jan 09 2026/19:00...              16
# 15  Linux Version 16.1.737.4870 (Jan 09 2026/19:00...              16
# 16  Linux Version 16.1.737.4870 (Jan 09 2026/19:00...              16
# 17  Linux Version 16.1.737.4870 (Jan 09 2026/19:00...              16
# 18  Linux Version 16.1.737.4870 (Jan 09 2026/19:00...              16
# 19  Linux Version 16.1.737.4870 (Jan 09 2026/19:00...              16
#
#     placement  level  gold_left  players_eliminated  total_damage_to_players  \
# 0           1      8          2                   2                      159
# 1           3      9          1                   1                      168
# 2           3      9          1                   0                      113
# 3           4      9          4                   1                       99
# 4           1      8          3                   3                      137
# 5           6      8          1                   0                       57
# 6           3      9          0                   1                      135
# 7           3     10          3                   1                       94
# 8           2     10          1                   1                      141
# 9           1      9         57                   4                      179
# 10          1      9          2                   3                      183
# 11          2      9          1                   1                      146
# 12          5      9          4                   0                       97
# 13          3      8          9                   0                       64
# 14          1     10         17                   2                      209
# 15          6      8         51                   1                       85
# 16          7      8         11                   0                       78
# 17          5      3          2                   0                        0
# 18          6      9          0                   0                       63
# 19          5      8          0                   1                      104
#
#                                         active_traits  \
# 0   TFT16_Defender, TFT16_Juggernaut, TFT16_Kindre...
# 1   TFT16_Bilgewater, TFT16_Brawler, TFT16_Glutton...
# 2   TFT16_Bilgewater, TFT16_Brawler, TFT16_Harvest...
# 3   TFT16_Brawler, TFT16_Defender, TFT16_Ionia, TF...
# 4   TFT16_Defender, TFT16_Emperor, TFT16_Magus, TF...
# 5   TFT16_Defender, TFT16_Demacia, TFT16_Ionia, TF...
# 6   TFT16_Defender, TFT16_Demacia, TFT16_Heroic, T...
# 7   TFT16_Chronokeeper, TFT16_Defender, TFT16_Dema...
# 8   TFT16_Bilgewater, TFT16_Brawler, TFT16_Glutton...
# 9   TFT16_Defender, TFT16_Demacia, TFT16_Heroic, T...
# 10  TFT16_Defender, TFT16_Demacia, TFT16_Heroic, T...
# 11  TFT16_Bilgewater, TFT16_Brawler, TFT16_Glutton...
# 12  TFT16_Blacksmith, TFT16_Brawler, TFT16_Freljor...
# 13  TFT16_Bilgewater, TFT16_Brawler, TFT16_Glutton...
# 14  TFT16_Brawler, TFT16_Harvester, TFT16_Ionia, T...
# 15  TFT16_Blacksmith, TFT16_Brawler, TFT16_Freljor...
# 16  TFT16_Brawler, TFT16_Juggernaut, TFT16_KaisaUn...
# 17
# 18  TFT16_Bilgewater, TFT16_Brawler, TFT16_Glutton...
# 19  TFT16_Bilgewater, TFT16_Juggernaut, TFT16_Noxu...
#
#                                                 units  num_units
# 0   TFT16_Neeko, TFT16_Vi, TFT16_Ekko, TFT16_Serap...          8
# 1   TFT16_TwistedFate, TFT16_MissFortune, TFT16_Ta...          9
# 2   TFT16_Illaoi, TFT16_Sion, TFT16_RekSai, TFT16_...          9
# 3   TFT16_Caitlyn, TFT16_Vi, TFT16_Kennen, TFT16_D...          9
# 4   TFT16_Neeko, TFT16_Vi, TFT16_Seraphine, TFT16_...          8
# 5   TFT16_JarvanIV, TFT16_Sona, TFT16_XinZhao, TFT...          8
# 6   TFT16_JarvanIV, TFT16_Sona, TFT16_XinZhao, TFT...         10
# 7   TFT16_JarvanIV, TFT16_Sona, TFT16_Poppy, TFT16...         11
# 8   TFT16_Graves, TFT16_Poppy, TFT16_Kobuko, TFT16...         10
# 9   TFT16_JarvanIV, TFT16_Sona, TFT16_Taric, TFT16...         10
# 10  TFT16_JarvanIV, TFT16_KogMaw, TFT16_XinZhao, T...         11
# 11  TFT16_TwistedFate, TFT16_Nautilus, TFT16_Loris...          9
# 12  TFT16_Anivia, TFT16_Ashe, TFT16_Sejuani, TFT16...          9
# 13  TFT16_TwistedFate, TFT16_Graves, TFT16_MissFor...          8
# 14  TFT16_Ahri, TFT16_Kennen, TFT16_Wukong, TFT16_...         10
# 15  TFT16_Ashe, TFT16_Tryndamere, TFT16_Sejuani, T...          8
# 16  TFT16_KogMaw, TFT16_RekSai, TFT16_ChoGath, TFT...          8
# 17                         TFT16_Qiyana, TFT16_Qiyana          2
# 18  TFT16_TwistedFate, TFT16_Nautilus, TFT16_MissF...         10
# 19  TFT16_Briar, TFT16_TwistedFate, TFT16_Nautilus...          8
